# %%
# %matplotlib inline
from matplotlib import pyplot as plt

plt.plot([1,2,3], [110,130,120])
plt.show()

# %%
from matplotlib import pyplot as plt

plt.plot(["seoul","paris","seattle"], [30,25,55])
plt.xlabel('city')
plt.ylabel('response')
plt.title('experiment result')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.plot([1,2,3], [1,4,9])
plt.plot([2,3,4], [5,6,7])
plt.xlabel('sequencecity')
plt.ylabel('time(secs)')
plt.title('experiment result')
plt.legend(['mouse','cat'])
plt.show()

# %%
from matplotlib import pyplot as plt

y = [5,3,7,10,9,5,3.5,8]
x = range(len(y))
plt.bar(x,y,width=0.7,color='blue')
plt.show()

# %%
import pandas as pd

data = [1,3,5,7,9]
s = pd.Series(data)
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
import pandas as pd

data = {
    'year':[2016,2017,2018],
    'GDP rate':[2.8,3.1,3.0],
    'GDP':['1.6M','1.7M','1.8M']
}
df = pd.DataFrame(data)
#df['year']
#df.year
#df[df['year'] > 2016]
#df['GDP rate'].sum() #총합
#df['GDP rate'].mean() #평균
#df
df.describe()
# Out:
#          year  GDP rate
# count     3.0  3.000000
# mean   2017.0  2.966667
# std       1.0  0.152753
# min    2016.0  2.800000
# 25%    2016.5  2.900000
# 50%    2017.0  3.000000
# 75%    2017.5  3.050000
# max    2018.0  3.100000

# %%
import pandas as pd
import numpy as np

data = np.random.rand(2,3,4)
data[0]
#p = pd.Panel(data)
# Out:
# array([[0.30194159, 0.77660883, 0.85567465, 0.95255234],
#        [0.15414458, 0.66110034, 0.69474885, 0.38668637],
#        [0.50195946, 0.49403167, 0.20264475, 0.60824883]])

# %%
import pandas as pd
from matplotlib import pyplot as plt

#df = pd.read_excel('score.xlsx')
df = pd.read_csv('score.csv')
plt.bar(df.ID, df['국어'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-47-74bd8c338f07> in <module>
#       3
#       4 #df = pd.read_excel('score.xlsx')
# ----> 5 df = pd.read_csv('score.csv')
#       6 plt.bar(df.ID, df['국어'])
#       7 plt.show()
#
# d:\githubmolo\devpython\venv\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# d:\githubmolo\devpython\venv\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# d:\githubmolo\devpython\venv\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# d:\githubmolo\devpython\venv\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 6, saw 3

# %%
from PIL import Image

im = Image.open("back_large.png")
print(im.size)

size = (60,60)
#im.thumbnail(size)
#im.save("back-thumb.jpg")

#크기변경
#img2 = im.resize((20,20))
#img2.save("back-resize.jpg")

#회전
#img3 = im.rotate(90)
#img3.save("back-rotate.jpg")
# Out:
# (48, 48)
